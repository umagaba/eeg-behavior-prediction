# %%
# !pip install -U braindecode==1.2.0 mne==1.10.1 mne-bids==0.17.0 --quiet
# !pip install -U eegdash==0.3.8 s3fs==2025.9.0 fsspec==2025.9.0 pandas==2.3.3 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 75.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 138.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.7/215.7 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 146.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 32.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 20.4 MB/s eta 0:00:00
#   Building wheel for docopt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.

# %%
from pathlib import Path
import os, math, random
from collections import defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.nn.utils import clip_grad_norm_

from sklearn.preprocessing import StandardScaler

from braindecode.preprocessing import create_fixed_length_windows
from braindecode.datasets.base import BaseConcatDataset, BaseDataset, EEGWindowsDataset
from braindecode.models import EEGNetv4  # EEGNet architecture implemented in Braindecode

from eegdash import EEGChallengeDataset

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
def seed_all(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
seed_all(42)
print("Device:", device)

# Sampling rate defined early
SFREQ = 100  # competition downsampled rate
# Out:
# Device: cuda

# %% [markdown]
# Loading data for one release

# %%
DATA_DIR = Path("data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

# Official split
train_releases = ["R1", "R2", "R3", "R4", "R6", "R7", "R8", "R9", "R10", "R11"]
val_releases   = ["R5"]
# test_releases  = ["R12"]  # R12 available only on cluster; code submission needed

task_name = "contrastChangeDetection"
mini_mode = True  # keep True for Colab/Kaggle; set False on a server with more RAM/disk

desc_fields = ["subject","session","run","task","age","sex","gender","handedness","p_factor"]

# Build training dataset by concatenating all training releases
print("Loading training releases:", train_releases)
train_list = [
    EEGChallengeDataset(
        release=rel,
        task=task_name,
        mini=mini_mode,
        description_fields=desc_fields,
        cache_dir=DATA_DIR,
    )
    for rel in train_releases
]
train_bcd_raw = BaseConcatDataset(train_list)
print("Raw train rows:", len(train_bcd_raw.datasets))

# Build validation dataset from R5
print("Loading validation release:", val_releases)
val_list = [
    EEGChallengeDataset(
        release=rel,
        task=task_name,
        mini=mini_mode,
        description_fields=desc_fields,
        cache_dir=DATA_DIR,
    )
    for rel in val_releases
]
val_bcd_raw = BaseConcatDataset(val_list)
print("Raw val rows:", len(val_bcd_raw.datasets))
# Out:
# Loading training releases: ['R1', 'R2', 'R3', 'R4', 'R6', 'R7', 'R8', 'R9', 'R10', 'R11']
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# Raw train rows: 597
# Loading validation release: ['R5']
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# Raw val rows: 60

# %% [markdown]
# Filtering and splitting

# %%
sub_rm =[]

def filter_dataset(bcd: BaseConcatDataset):
    kept = []
    for ds in bcd.datasets:
        ok = (
            ds.description["subject"] not in sub_rm
            and not math.isnan(float(ds.description.get("p_factor", np.nan)))
            and ds.raw.n_times >= 4 * SFREQ
            and len(ds.raw.ch_names) == 129
        )
        if ok:
            kept.append(ds)
    return BaseConcatDataset(kept)

train_bcd = filter_dataset(train_bcd_raw)
val_bcd   = filter_dataset(val_bcd_raw)

print("Filtered train rows:", len(train_bcd.datasets))
print("Filtered val rows:", len(val_bcd.datasets))

# Count unique subjects per split
train_subjects = set(ds.description["subject"] for ds in train_bcd.datasets)
val_subjects   = set(ds.description["subject"] for ds in val_bcd.datasets)
print(f"Train subjects: {len(train_subjects)} | Val subjects: {len(val_subjects)}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARNJ899HW7_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.51B/s]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARNJ899HW7_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.91B/s]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.14B/s]
# Downloading sub-NDARNJ899HW7_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDARNJ899HW7_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.66B/s]
# Downloading sub-NDARNJ899HW7_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARNJ899HW7_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.15s/B]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.18B/s]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.86B/s]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.49B/s]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.57B/s]
# Downloading sub-NDARNJ899HW7_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.76B/s]
# Downloading dataset_description.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading participants.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.89B/s]
# Downloading sub-NDARAY475AKD_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.79B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARAY475AKD_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.70B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARAY475AKD_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.88B/s]
# Downloading sub-NDARAY475AKD_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDARAY475AKD_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.70B/s]
# Downloading sub-NDARAY475AKD_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARAY475AKD_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.57B/s]
# Downloading sub-NDARAY475AKD_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.29B/s]
# Downloading sub-NDARAY475AKD_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.90B/s]
# Downloading task-seqLearning8target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading task-RestingState_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading task-surroundSupp_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.88B/s]
# Downloading task-FunwithFractals_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading task-symbolSearch_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.69B/s]
# Downloading task-ThePresent_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.84B/s]
# Downloading task-seqLearning6target_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.76B/s]
# Downloading task-contrastChangeDetection_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.02B/s]
# Downloading task-DespicableMe_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading task-DiaryOfAWimpyKid_events.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.02B/s]
# Downloading sub-NDARAY475AKD_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARAY475AKD_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARAY475AKD_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.75B/s]
# Downloading sub-NDARAY475AKD_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARAY475AKD_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARAY475AKD_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.92B/s]
# Downloading sub-NDARAY475AKD_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.54B/s]
# Downloading sub-NDARAY475AKD_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.33B/s]
# Downloading sub-NDARAY475AKD_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.03B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.32B/s]
# Downloading task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading task-surroundSupp_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading task-contrastChangeDetection_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.01B/s]
# Downloading task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.26B/s]
# Downloading task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDARAY475AKD_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.82B/s]
# Downloading sub-NDARAY475AKD_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.89B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDARAY475AKD_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDARAY475AKD_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.86B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARAY475AKD_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading sub-NDARAY475AKD_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.62B/s]
# Downloading sub-NDARAY475AKD_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.48B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.79B/s]
# Downloading sub-NDARAY475AKD_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDARAY475AKD_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.20s/B]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.14B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.21B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.32B/s]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.12s/B]
# Downloading sub-NDARAY475AKD_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.06s/B]
# Downloading sub-NDARBW026UGE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDARBW026UGE_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.62B/s]
# Downloading sub-NDARBW026UGE_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.95B/s]
# Downloading sub-NDARBW026UGE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.30B/s]
# Downloading sub-NDARBW026UGE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARBW026UGE_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.79B/s]
# Downloading sub-NDARBW026UGE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDARBW026UGE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.73B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDARBW026UGE_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARBW026UGE_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]
# Downloading sub-NDARBW026UGE_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.14B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARBW026UGE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARBW026UGE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARBW026UGE_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDARBW026UGE_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.68B/s]
# Downloading sub-NDARBW026UGE_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.67B/s]
# Downloading sub-NDARBW026UGE_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDARBW026UGE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.86B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.63B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.11B/s]
# Downloading sub-NDARBW026UGE_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.66B/s]
# Downloading sub-NDARBW026UGE_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.02B/s]
# Downloading sub-NDARBW026UGE_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.61B/s]
# Downloading sub-NDARBW026UGE_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.85B/s]
# Downloading sub-NDARBW026UGE_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARBW026UGE_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.46B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARBW026UGE_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.73B/s]
# Downloading sub-NDARBW026UGE_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.93B/s]
# Downloading sub-NDARBW026UGE_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.54B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.13s/B]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.41s/B]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.30B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.15B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.11B/s]
# Downloading sub-NDARBW026UGE_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.16B/s]
# Downloading sub-NDARCK162REX_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.58B/s]
# Downloading sub-NDARCK162REX_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.87B/s]
# Downloading sub-NDARCK162REX_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading sub-NDARCK162REX_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.34B/s]
# Downloading sub-NDARCK162REX_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.56B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARCK162REX_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.48B/s]
# Downloading sub-NDARCK162REX_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDARCK162REX_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.82B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARCK162REX_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDARCK162REX_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.03B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.78B/s]
# Downloading sub-NDARCK162REX_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.14B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.37B/s]
# Downloading sub-NDARCK162REX_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCK162REX_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.90B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.95B/s]
# Downloading sub-NDARCK162REX_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDARCK162REX_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.76B/s]
# Downloading sub-NDARCK162REX_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARCK162REX_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDARCK162REX_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.67B/s]
# Downloading sub-NDARCK162REX_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARCK162REX_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.01B/s]
# Downloading sub-NDARCK162REX_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARCK162REX_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.05B/s]
# Downloading sub-NDARCK162REX_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.96B/s]
# Downloading sub-NDARCK162REX_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.44B/s]
# Downloading sub-NDARCK162REX_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.01B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDARCK162REX_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.87B/s]
# Downloading sub-NDARCK162REX_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.32s/B]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.33B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.65B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.17B/s]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.04s/B]
# Downloading sub-NDARCK162REX_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.07s/B]
# Downloading sub-NDARCK481KRH_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.84B/s]
# Downloading sub-NDARCK481KRH_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.95B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDARCK481KRH_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.73B/s]
# Downloading sub-NDARCK481KRH_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.36B/s]
# Downloading sub-NDARCK481KRH_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.62B/s]
# Downloading sub-NDARCK481KRH_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.12B/s]
# Downloading sub-NDARCK481KRH_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.28B/s]
# Downloading sub-NDARCK481KRH_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCK481KRH_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.03B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.83B/s]
# Downloading sub-NDARCK481KRH_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDARCK481KRH_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDARCK481KRH_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.85B/s]
# Downloading sub-NDARCK481KRH_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDARCK481KRH_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.63B/s]
# Downloading sub-NDARCK481KRH_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.86B/s]
# Downloading sub-NDARCK481KRH_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading sub-NDARCK481KRH_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARCK481KRH_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCK481KRH_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDARCK481KRH_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.82B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDARCK481KRH_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDARCK481KRH_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARCK481KRH_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCK481KRH_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCK481KRH_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARCK481KRH_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.46B/s]
# Downloading sub-NDARCK481KRH_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.23s/B]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.32B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.62B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.54B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.40B/s]
# Downloading sub-NDARCK481KRH_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.31B/s]
# Downloading sub-NDARCV378MMX_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDARCV378MMX_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.03B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDARCV378MMX_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARCV378MMX_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARCV378MMX_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.88B/s]
# Downloading sub-NDARCV378MMX_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARCV378MMX_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.36B/s]
# Downloading sub-NDARCV378MMX_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.51B/s]
# Downloading sub-NDARCV378MMX_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.12B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.07B/s]
# Downloading sub-NDARCV378MMX_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDARCV378MMX_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDARCV378MMX_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.89B/s]
# Downloading sub-NDARCV378MMX_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDARCV378MMX_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.91B/s]
# Downloading sub-NDARCV378MMX_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.24B/s]
# Downloading sub-NDARCV378MMX_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.57B/s]
# Downloading sub-NDARCV378MMX_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.03B/s]
# Downloading sub-NDARCV378MMX_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARCV378MMX_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.75B/s]
# Downloading sub-NDARCV378MMX_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.93B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDARCV378MMX_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.89B/s]
# Downloading sub-NDARCV378MMX_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARCV378MMX_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.18B/s]
# Downloading sub-NDARCV378MMX_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.76B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARCV378MMX_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARCV378MMX_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARCV378MMX_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.85B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.12s/B]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.80B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.29B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.81B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.91B/s]
# Downloading sub-NDARCV378MMX_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.09B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.66B/s]
# Downloading sub-NDARCX462NVA_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARCX462NVA_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.98B/s]
# Downloading sub-NDARCX462NVA_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARCX462NVA_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARCX462NVA_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARCX462NVA_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.35B/s]
# Downloading sub-NDARCX462NVA_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.80B/s]
# Downloading sub-NDARCX462NVA_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.61B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARCX462NVA_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.83B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.83B/s]
# Downloading sub-NDARCX462NVA_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.50B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.52B/s]
# Downloading sub-NDARCX462NVA_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.37B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCX462NVA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.60B/s]
# Downloading sub-NDARCX462NVA_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARCX462NVA_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.12B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDARCX462NVA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]
# Downloading sub-NDARCX462NVA_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARCX462NVA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARCX462NVA_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.34B/s]
# Downloading sub-NDARCX462NVA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.02B/s]
# Downloading sub-NDARCX462NVA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.02B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDARCX462NVA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.78B/s]
# Downloading sub-NDARCX462NVA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.89B/s]
# Downloading sub-NDARCX462NVA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.82B/s]
# Downloading sub-NDARCX462NVA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARCX462NVA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.96B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARCX462NVA_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.91B/s]
# Downloading sub-NDARCX462NVA_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.16s/B]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.23B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.71B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.10B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.84B/s]
# Downloading sub-NDARCX462NVA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.22B/s]
# Downloading sub-NDARDJ970ELG_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.91B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.73B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARDJ970ELG_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.30B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDARDJ970ELG_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARDJ970ELG_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.47B/s]
# Downloading sub-NDARDJ970ELG_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.85B/s]
# Downloading sub-NDARDJ970ELG_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.93B/s]
# Downloading sub-NDARDJ970ELG_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDARDJ970ELG_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.75B/s]
# Downloading sub-NDARDJ970ELG_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.46B/s]
# Downloading sub-NDARDJ970ELG_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.11B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.58B/s]
# Downloading sub-NDARDJ970ELG_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDARDJ970ELG_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.86B/s]
# Downloading sub-NDARDJ970ELG_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.78B/s]
# Downloading sub-NDARDJ970ELG_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.77B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARDJ970ELG_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDARDJ970ELG_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARDJ970ELG_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.78B/s]
# Downloading sub-NDARDJ970ELG_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.78B/s]
# Downloading sub-NDARDJ970ELG_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARDJ970ELG_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.68B/s]
# Downloading sub-NDARDJ970ELG_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.97B/s]
# Downloading sub-NDARDJ970ELG_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.09B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.78B/s]
# Downloading sub-NDARDJ970ELG_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.90B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDARDJ970ELG_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDARDJ970ELG_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.42B/s]
# Downloading sub-NDARDJ970ELG_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARDJ970ELG_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.60B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.31B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.30s/B]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.24B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.95B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.19B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.87B/s]
# Downloading sub-NDARDJ970ELG_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.20B/s]
# Downloading sub-NDARDU617ZW1_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.82B/s]
# Downloading sub-NDARDU617ZW1_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.64B/s]
# Downloading sub-NDARDU617ZW1_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARDU617ZW1_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.77B/s]
# Downloading sub-NDARDU617ZW1_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDARDU617ZW1_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.84B/s]
# Downloading sub-NDARDU617ZW1_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDARDU617ZW1_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.98B/s]
# Downloading sub-NDARDU617ZW1_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading sub-NDARDU617ZW1_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.83B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDARDU617ZW1_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDARDU617ZW1_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.82B/s]
# Downloading sub-NDARDU617ZW1_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.07B/s]
# Downloading sub-NDARDU617ZW1_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.66B/s]
# Downloading sub-NDARDU617ZW1_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.80B/s]
# Downloading sub-NDARDU617ZW1_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.38B/s]
# Downloading sub-NDARDU617ZW1_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.69B/s]
# Downloading sub-NDARDU617ZW1_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARDU617ZW1_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.03B/s]
# Downloading sub-NDARDU617ZW1_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARDU617ZW1_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.82B/s]
# Downloading sub-NDARDU617ZW1_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.85B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDARDU617ZW1_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDARDU617ZW1_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.68B/s]
# Downloading sub-NDARDU617ZW1_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.42B/s]
# Downloading sub-NDARDU617ZW1_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.02B/s]
# Downloading sub-NDARDU617ZW1_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.29B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.11s/B]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.49B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.99B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.24B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.80B/s]
# Downloading sub-NDARDU617ZW1_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.82B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDAREM609ZXW_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.60B/s]
# Downloading sub-NDAREM609ZXW_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.31B/s]
# Downloading sub-NDAREM609ZXW_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.67B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDAREM609ZXW_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.79B/s]
# Downloading sub-NDAREM609ZXW_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.93B/s]
# Downloading sub-NDAREM609ZXW_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDAREM609ZXW_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDAREM609ZXW_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading sub-NDAREM609ZXW_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.03B/s]
# Downloading sub-NDAREM609ZXW_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.92B/s]
# Downloading sub-NDAREM609ZXW_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.80B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.10B/s]
# Downloading sub-NDAREM609ZXW_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDAREM609ZXW_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.44B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.99B/s]
# Downloading sub-NDAREM609ZXW_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.90B/s]
# Downloading sub-NDAREM609ZXW_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.86B/s]
# Downloading sub-NDAREM609ZXW_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDAREM609ZXW_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.93B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDAREM609ZXW_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.83B/s]
# Downloading sub-NDAREM609ZXW_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.95B/s]
# Downloading sub-NDAREM609ZXW_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.06B/s]
# Downloading sub-NDAREM609ZXW_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDAREM609ZXW_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.63B/s]
# Downloading sub-NDAREM609ZXW_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.87B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.94B/s]
# Downloading sub-NDAREM609ZXW_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDAREM609ZXW_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.80B/s]
# Downloading sub-NDAREM609ZXW_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDAREM609ZXW_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.05B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.17s/B]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.16B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.26B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.90B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.87B/s]
# Downloading sub-NDAREM609ZXW_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.49B/s]
# Downloading sub-NDAREW074ZM2_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.74B/s]
# ...
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.01B/s]
# Downloading sub-NDARDL305BT8_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.07B/s]
# Downloading sub-NDARDL305BT8_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.14B/s]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.44s/B]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.48B/s]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.68B/s]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.66B/s]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.99B/s]
# Downloading sub-NDARDL305BT8_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.13B/s]
# Downloading sub-NDARDU853XZ6_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDARDU853XZ6_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.26B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDARDU853XZ6_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDARDU853XZ6_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.14B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDARDU853XZ6_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.32B/s]
# Downloading sub-NDARDU853XZ6_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.25B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.11B/s]
# Downloading sub-NDARDU853XZ6_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.26B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARDU853XZ6_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARDU853XZ6_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARDU853XZ6_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARDU853XZ6_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]
# Downloading sub-NDARDU853XZ6_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.96B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.28B/s]
# Downloading sub-NDARDU853XZ6_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.29B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARDU853XZ6_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.29B/s]
# Downloading sub-NDARDU853XZ6_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDARDU853XZ6_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARDU853XZ6_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDARDU853XZ6_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.31B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.95B/s]
# Downloading sub-NDARDU853XZ6_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARDU853XZ6_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.28B/s]
# Downloading sub-NDARDU853XZ6_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARDU853XZ6_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.28B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.22s/B]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.20B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.11B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.27B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.97B/s]
# Downloading sub-NDARDU853XZ6_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.24B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.26B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.13B/s]
# Downloading sub-NDARDV245WJG_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDARDV245WJG_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.40B/s]
# Downloading sub-NDARDV245WJG_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDARDV245WJG_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.29B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.95B/s]
# Downloading sub-NDARDV245WJG_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.09B/s]
# Downloading sub-NDARDV245WJG_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDARDV245WJG_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.96B/s]
# Downloading sub-NDARDV245WJG_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.26B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.75B/s]
# Downloading sub-NDARDV245WJG_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.78B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDARDV245WJG_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDARDV245WJG_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARDV245WJG_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDARDV245WJG_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARDV245WJG_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.25B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.00B/s]
# Downloading sub-NDARDV245WJG_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]
# Downloading sub-NDARDV245WJG_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.12B/s]
# Downloading sub-NDARDV245WJG_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDARDV245WJG_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.84B/s]
# Downloading sub-NDARDV245WJG_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDARDV245WJG_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDARDV245WJG_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.89B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.16B/s]
# Downloading sub-NDARDV245WJG_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.03B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.01B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.83B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.96B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.21B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.51B/s]
# Downloading sub-NDARDV245WJG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.78B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.23B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.32B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.15B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.22B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.18B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.08B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.25B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.63B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.96B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.28B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.24B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.27B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.28B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.25B/s]
# Downloading sub-NDAREC480KFA_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.14B/s]
# Downloading sub-NDAREC480KFA_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.21B/s]
# Downloading sub-NDAREC480KFA_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.20B/s]
# Downloading sub-NDAREC480KFA_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.16B/s]
# Downloading sub-NDAREC480KFA_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.17B/s]
# Downloading sub-NDAREC480KFA_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.56B/s]
# Downloading sub-NDAREC480KFA_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.93B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.19B/s]
# Downloading sub-NDAREC480KFA_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.04B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.52s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.17s/B]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.30B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.52B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.31B/s]
# Downloading sub-NDAREC480KFA_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.15B/s]
# Filtered train rows: 597
# Filtered val rows: 57
# Train subjects: 199 | Val subjects: 19

# %%
import pickle
from pathlib import Path

# Save filtered datasets
train_cache = Path("data/train_bcd_filtered.pkl")
val_cache = Path("data/val_bcd_filtered.pkl")

train_cache.parent.mkdir(parents=True, exist_ok=True)

print("Saving filtered datasets...")
with open(train_cache, "wb") as f:
    pickle.dump(train_bcd, f)
with open(val_cache, "wb") as f:
    pickle.dump(val_bcd, f)
print(f"Saved to {train_cache} and {val_cache}")
print("Next time, load these instead of re-filtering.")
# Out:
# Saving filtered datasets...
# Saved to data/train_bcd_filtered.pkl and data/val_bcd_filtered.pkl
# Next time, load these instead of re-filtering.

# %%
print("Sample train subjects:", list(train_subjects)[:5])
print("Sample val subjects:", list(val_subjects)[:5])

# Label histogram for training
train_labels = np.array([float(ds.description["p_factor"]) for ds in train_bcd.datasets], dtype=np.float32)
val_labels   = np.array([float(ds.description["p_factor"]) for ds in val_bcd.datasets], dtype=np.float32)
print("Train p_factor: mean={:.3f}, std={:.3f}".format(train_labels.mean(), train_labels.std()))
print("Val p_factor: mean={:.3f}, std={:.3f}".format(val_labels.mean(), val_labels.std()))
# Out:
# Sample train subjects: ['NDARAP359UM6', 'NDAREK549XUQ', 'NDARBT640EBN', 'NDAREV527ZRF', 'NDARAD571FLB']
# Sample val subjects: ['NDARAU708TL8', 'NDARBM433VER', 'NDARBE103DHM', 'NDARDH086ZKK', 'NDARDC843HHM']
# Train p_factor: mean=-0.062, std=0.807
# Val p_factor: mean=-0.003, std=0.831

# %% [markdown]
# Dataset wrapper w/ demographics

# %%
class DatasetWrapper(BaseDataset):

    def __init__(self, dataset: EEGWindowsDataset, crop_size_samples: int, seed=None):
        self.dataset = dataset
        self.crop_size_samples = crop_size_samples
        self.rng = random.Random(seed)

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, index):
        X, _, crop_inds = self.dataset[index]

        # Label
        y = torch.tensor(float(self.dataset.description["p_factor"]), dtype=torch.float32)

        # Build full demo = [age, sex, hand]
        age = self.dataset.description.get("age", np.nan)
        age = float(age) if age is not None and age == age else np.nan
        sex_str = str(self.dataset.description.get("sex", self.dataset.description.get("gender", ""))).strip().lower()
        sex = 1.0 if sex_str in ["female","f","2"] else 0.0 if sex_str not in ["", "nan"] else np.nan
        hand = self.dataset.description.get("handedness", np.nan)
        hand = float(hand) if hand is not None and hand == hand else np.nan

        full_demo = np.array([age, sex, hand], dtype=np.float32)

        # Select only kept columns
        if demo_dim > 0:
            demo_np = full_demo[keep_idx]
            # Do not impute here; raw NaNs will be handled in transform function
            demo = torch.from_numpy(demo_np)
        else:
            demo = torch.empty(0, dtype=torch.float32)  # zero-dim


        infos = {
            "subject": self.dataset.description["subject"],
            "task": self.dataset.description["task"],
            "session": self.dataset.description.get("session", "") or "",
            "run": self.dataset.description.get("run", "") or "",
        }

        # Random 2 s crop inside a 4 s window
        i_window_in_trial, i_start, i_stop = crop_inds
        crop_len = 2 * SFREQ
        assert (i_stop - i_start) >= crop_len, f"Window too short: {(i_stop - i_start)} < {crop_len}"
        start_offset = self.rng.randint(0, (i_stop - i_start) - crop_len)
        X = X[:, start_offset : start_offset + crop_len]  # X may be numpy here

        # Convert to torch tensor (C, T) float32
        if not torch.is_tensor(X):
            X = torch.from_numpy(np.asarray(X))

        X = X.to(torch.float32)

        # Per-window standardization with epsilon, then sanitize
        mu = X.mean(dim=1, keepdim=True)
        sd = X.std(dim=1, keepdim=True)
        X = (X - mu) / (sd + 1e-6)

        # Replace NaN/Inf with zeros and clamp extreme amplitudes
        X = torch.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0)
        X = torch.clamp(X, min=-1e3, max=1e3)

        return X, y, demo, (i_window_in_trial, i_start, i_stop), infos

# %% [markdown]
# Fit demo scaler on train subjects

# %%
# Extract unique demographics from train_bcd for scaler fitting
def extract_unique_demo(bcd: BaseConcatDataset):
    seen = {}
    for ds in bcd.datasets:
        sid = ds.description["subject"]
        if sid in seen:
            continue
        age = ds.description.get("age", np.nan)
        age = float(age) if age is not None and age == age else np.nan
        sex_str = str(ds.description.get("sex", ds.description.get("gender", ""))).strip().lower()
        sex = 1.0 if sex_str in ["female","f","2"] else 0.0 if sex_str else np.nan
        hand = ds.description.get("handedness", np.nan)
        hand = float(hand) if hand is not None and hand == hand else np.nan
        seen[sid] = [age, sex, hand]
    arr = np.array(list(seen.values()), dtype=np.float32) if seen else np.zeros((0,3), dtype=np.float32)
    return arr

train_demo_unique = extract_unique_demo(train_bcd)
if train_demo_unique.shape[0] == 0:
    train_demo_unique = np.zeros((1,3), dtype=np.float32) * np.nan

# Detect all-NaN columns and keep only usable ones
all_nan_cols = np.isnan(train_demo_unique).all(axis=0)
keep_mask = ~all_nan_cols
keep_names = [n for n, k in zip(["age","sex","hand"], keep_mask) if k]
keep_idx = np.where(keep_mask)[0]
print("Keeping demo columns:", keep_names)

train_demo_kept = train_demo_unique[:, keep_idx]
if train_demo_kept.shape[1] == 0:
    print("No usable demographic columns; disabling late fusion.")
    demo_dim = 0
else:
    demo_dim = train_demo_kept.shape[1]

if demo_dim > 0:
    with np.errstate(all="ignore"):
        col_medians = np.nanmedian(train_demo_kept, axis=0).astype(np.float32)
    col_medians[~np.isfinite(col_medians)] = 0.0

    def impute_cols(arr, meds):
        out = arr.copy()
        for j in range(out.shape[1]):
            mask = ~np.isfinite(out[:, j])
            out[mask, j] = meds[j]
        return out

    train_demo_imp = impute_cols(train_demo_kept, col_medians)

    class SafeStandardScaler(StandardScaler):
        def fit(self, X, y=None):
            super().fit(X, y)
            if hasattr(self, "scale_"):
                bad = ~np.isfinite(self.scale_) | (self.scale_ == 0)
                self.scale_[bad] = 1.0
            if hasattr(self, "var_"):
                self.var_[~np.isfinite(self.var_)] = 0.0
            if hasattr(self, "mean_"):
                self.mean_[~np.isfinite(self.mean_)] = 0.0
            return self

    demo_scaler = SafeStandardScaler().fit(train_demo_imp)
    print("Demo scaler fitted on", train_demo_imp.shape[0], "training subjects | dims:", demo_dim)
else:
    demo_scaler = None
    col_medians = np.zeros(0, dtype=np.float32)

@torch.no_grad()
def transform_demo_batch(demo_t: torch.Tensor):

    dev = torch.device(device) if not isinstance(device, torch.device) else device

    # If demographics were dropped (demo_dim=0), return empty tensor
    if demo_t.numel() == 0:
        return demo_t.to(device=dev)

    # Convert to numpy, impute, scale
    demo_np = demo_t.detach().cpu().numpy().astype(np.float32)

    # Impute with col_medians (one per kept column)
    for j in range(demo_np.shape[1]):
        mask = ~np.isfinite(demo_np[:, j])
        demo_np[mask, j] = col_medians[j] if j < len(col_medians) else 0.0

    # Scale using fitted scaler
    demo_np = demo_scaler.transform(demo_np)

    # Convert back to torch and sanitize
    demo = torch.from_numpy(demo_np).to(device=dev, dtype=torch.float32)
    demo = torch.nan_to_num(demo, nan=0.0, posinf=0.0, neginf=0.0)

    return demo
# Out:
# Keeping demo columns: ['age', 'sex']
# Demo scaler fitted on 199 training subjects | dims: 2

# %% [markdown]
# Windowing and DataLoaders

# %%
def make_windows(bcd: BaseConcatDataset, crop_seconds=2):
    windows = create_fixed_length_windows(
        bcd,
        window_size_samples=4 * SFREQ,
        window_stride_samples=2 * SFREQ,
        drop_last_window=True,
    )
    wrapped = [DatasetWrapper(ds, crop_size_samples=crop_seconds * SFREQ, seed=42) for ds in windows.datasets]
    return BaseConcatDataset(wrapped)

train_windows = make_windows(train_bcd, crop_seconds=2)
val_windows   = make_windows(val_bcd,   crop_seconds=2)

num_workers = 1
batch_size = 128  # or 32/64 depending on GPU memory
train_loader = DataLoader(train_windows, batch_size=batch_size, shuffle=True,  num_workers=num_workers)
val_loader   = DataLoader(val_windows,   batch_size=batch_size, shuffle=False, num_workers=num_workers)
print("Train batches:", len(train_loader), "| Val batches:", len(val_loader))
# Out:
# Train batches: 765 | Val batches: 65

# %% [markdown]
# Visualization

# %%
# Sample a window and plot channels
if len(train_windows.datasets) > 0:
    sample_ds = train_windows.datasets[0]
    X_win, y_win, demo_win, _, info_win = sample_ds[0]
    print("Sample window:", X_win.shape, "y:", float(y_win), "demo:", demo_win.numpy(), "subject:", info_win["subject"])

    t = np.arange(X_win.shape[1]) / SFREQ
    plt.figure(figsize=(10, 5))
    for ch in [0, 32, 64, 96]:
        if ch < X_win.shape[0]:
            plt.plot(t, X_win[ch], label=f"Ch {ch}")
    plt.xlabel("Time (s)"); plt.ylabel("Amplitude (a.u.)"); plt.title("Windowed EEG (sample channels)")
    plt.legend(); plt.tight_layout(); plt.show()

# Histogram of training p_factor (unique subjects)
def unique_subject_labels(bcd):
    seen = {}
    for ds in bcd.datasets:
        sid = ds.description["subject"]
        if sid not in seen:
            seen[sid] = float(ds.description["p_factor"])
    return np.array(list(seen.values()), dtype=np.float32) if seen else np.zeros((0,), dtype=np.float32)

train_labels = unique_subject_labels(train_bcd)
if train_labels.size > 0:
    plt.figure(figsize=(6,4))
    plt.hist(train_labels, bins=20, edgecolor="black")
    plt.xlabel("p_factor"); plt.ylabel("Count"); plt.title("Training subjects: p_factor distribution")
    plt.tight_layout(); plt.show()
# Out:
# Sample window: torch.Size([129, 200]) y: -0.6029999852180481 demo: [11.3386  1.    ] subject: NDARAC904DMU

# %% [markdown]
# EEGNetv4 + demographics late fusion

# %%
class EEGNetWithDemo(nn.Module):
    def __init__(self, n_chans, n_times, demo_dim=3, feat_dim=16, drop_prob=0.5):
        super().__init__()
        self.backbone = EEGNetv4(n_chans=n_chans, n_outputs=feat_dim, n_times=n_times, drop_prob=drop_prob)
        self.head = nn.Sequential(
            nn.Linear(feat_dim + demo_dim, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.25),
            nn.Linear(64, 1),
        )
    def forward(self, x, demo):
        feat = self.backbone(x)             # [B, feat_dim]
        z = torch.cat([feat, demo], dim=1)  # [B, feat_dim + demo_dim]
        return self.head(z)                 # [B, 1]

if demo_dim > 0:
    model = EEGNetWithDemo(n_chans=129, n_times=2 * SFREQ, demo_dim=demo_dim, feat_dim=16, drop_prob=0.5).to(device)
else:
    # EEG-only: set EEGNetv4 to output 1 directly or keep feat_dim + head with demo_dim=0
    class EEGOnly(nn.Module):
        def __init__(self, n_chans, n_times, feat_dim=16, drop_prob=0.5):
            super().__init__()
            self.backbone = EEGNetv4(n_chans=n_chans, n_outputs=feat_dim, n_times=n_times, drop_prob=drop_prob)
            self.head = nn.Sequential(nn.Linear(feat_dim, 64), nn.ReLU(inplace=True), nn.Dropout(p=0.25), nn.Linear(64, 1))
        def forward(self, x):
            feat = self.backbone(x)
            return self.head(feat)
    model = EEGOnly(n_chans=129, n_times=2 * SFREQ, feat_dim=16, drop_prob=0.5).to(device)

optimizer = torch.optim.Adamax(model.parameters(), lr=0.002, weight_decay=1e-3)
criterion = torch.nn.MSELoss()  # aligns with RMSE/nRMSE scoring
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="min", factor=0.5, patience=3, min_lr=1e-5)
print(model)
# Out:
# <decorator-gen-593>:4: FutureWarning: NOTE: EEGNetv4() is a deprecated class. `EEGNetv4` was renamed to `EEGNet` in v1.12; this alias will be removed in v1.14..
# EEGNetWithDemo(
#   (backbone): EEGNetv4(
#     (ensuredims): Ensure4d()
#     (dimshuffle): Rearrange('batch ch t 1 -> batch 1 ch t')
#     (conv_temporal): Conv2d(1, 8, kernel_size=(1, 64), stride=(1, 1), padding=(0, 32), bias=False)
#     (bnorm_temporal): BatchNorm2d(8, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (conv_spatial): ParametrizedConv2dWithConstraint(
#       8, 16, kernel_size=(129, 1), stride=(1, 1), groups=8, bias=False
#       (parametrizations): ModuleDict(
#         (weight): ParametrizationList(
#           (0): MaxNormParametrize()
#         )
#       )
#     )
#     (bnorm_1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (elu_1): ELU(alpha=1.0)
#     (pool_1): AvgPool2d(kernel_size=(1, 4), stride=(1, 4), padding=0)
#     (drop_1): Dropout(p=0.5, inplace=False)
#     (conv_separable_depth): Conv2d(16, 16, kernel_size=(1, 16), stride=(1, 1), padding=(0, 8), groups=16, bias=False)
#     (conv_separable_point): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bnorm_2): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (elu_2): ELU(alpha=1.0)
#     (pool_2): AvgPool2d(kernel_size=(1, 8), stride=(1, 8), padding=0)
#     (drop_2): Dropout(p=0.5, inplace=False)
#     (final_layer): Sequential(
#       (conv_classifier): Conv2d(16, 16, kernel_size=(1, 6), stride=(1, 1))
#       (permute_back): Rearrange('batch x y z -> batch x z y')
#       (squeeze): SqueezeFinalOutput(
#         (squeeze): Rearrange('b c t 1 -> b c t')
#       )
#     )
#   )
#   (head): Sequential(
#     (0): Linear(in_features=18, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# Validation: subject-level nRMSE

# %%
@torch.no_grad()
def evaluate_subject_nrmse(model, loader):
    model.eval()
    dev = torch.device(device) if not isinstance(device, torch.device) else device
    subj_pred, subj_true = defaultdict(list), {}

    # Progress bar for validation batches
    pbar = tqdm(loader, desc="Validation", leave=False)
    for X, y, demo, crop_inds, infos in pbar:
        X = X.to(device=dev, dtype=torch.float32)
        y = y.to(device=dev, dtype=torch.float32).view(-1, 1)
        demo = transform_demo_batch(demo)
        if demo.device != dev:
            demo = demo.to(device=dev, dtype=torch.float32)

        preds = model(X, demo).squeeze(1).detach().cpu().numpy()
        ys    = y.squeeze(1).detach().cpu().numpy()

        subjects = [d["subject"] for d in infos] if isinstance(infos, list) else infos["subject"]
        if not isinstance(subjects, (list, tuple, np.ndarray)):
            subjects = [subjects] * len(preds)

        for i, sid in enumerate(subjects):
            subj_pred[sid].append(float(preds[i]))
            subj_true[sid] = float(ys[i])

    # Aggregate and compute nRMSE
    y_true, y_hat, sids = [], [], []
    for sid, pred_list in subj_pred.items():
        if sid not in subj_true or len(pred_list) == 0:
            continue
        y_true.append(subj_true[sid])
        y_hat.append(float(np.mean(pred_list)))
        sids.append(sid)

    y_true = np.array(y_true, dtype=np.float64)
    y_hat  = np.array(y_hat,  dtype=np.float64)
    if len(y_true) == 0:
        return np.nan, np.nan, np.nan, 0

    rmse  = np.sqrt(np.mean((y_true - y_hat) ** 2))
    std_y = np.std(y_true, ddof=0)
    nrmse = rmse / std_y if std_y > 0 else np.nan

    # Save CSV
    out_path = Path("outputs"); out_path.mkdir(parents=True, exist_ok=True)
    pd.DataFrame({"subject": sids, "p_factor_pred": y_hat}).to_csv(out_path / "val_subject_predictions.csv", index=False)

    return nrmse, rmse, std_y, len(sids)

# %% [markdown]
# Training with early stopping

# %%
from tqdm.auto import tqdm

n_epochs = 40
best_nrmse = float("inf")
patience = 8
wait = 0

ckpt_dir = Path("checkpoints"); ckpt_dir.mkdir(parents=True, exist_ok=True)
ckpt_path = ckpt_dir / "best_eegnet_demo_r5.pt"

for epoch in range(1, n_epochs + 1):
    # Train
    model.train()
    train_loss_sum, train_count = 0.0, 0
    for X, y, demo, crop_inds, infos in tqdm(train_loader, desc=f"Epoch {epoch:02d} Train", leave=False):
        optimizer.zero_grad()
        X = X.to(device=device, dtype=torch.float32)
        y = y.to(device=device, dtype=torch.float32).view(-1, 1)
        demo = demo.to(device=device, dtype=torch.float32)
        y_pred = model(X, demo)
        loss = criterion(y_pred, y)
        if not torch.isfinite(y_pred).all() or not torch.isfinite(y).all():
          print("Non-finite detected:", torch.isnan(y_pred).sum().item(), torch.isinf(y_pred).sum().item())
          continue

        loss.backward()
        clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        train_loss_sum += loss.item() * X.size(0)
        train_count += X.size(0)
    train_mse = train_loss_sum / max(1, train_count)

    # Validate (subject-level on R5 split)
    nrmse, rmse, std_y, n_subj = evaluate_subject_nrmse(model, val_loader)
    scheduler.step(nrmse if nrmse == nrmse else 1.0)

    print(f"Epoch {epoch:02d} | train MSE={train_mse:.4f} | val nRMSE={nrmse:.4f} | RMSE={rmse:.4f} | std(y)={std_y:.4f} | subjects={n_subj}")

    # Early stopping
    if nrmse < best_nrmse:
        best_nrmse = nrmse
        wait = 0
        torch.save({"model": model.state_dict(), "best_nrmse": best_nrmse}, ckpt_path)
        print(f"  Saved: {ckpt_path} (best nRMSE={best_nrmse:.4f})")
    else:
        wait += 1
        if wait >= patience:
            print(f"Early stopping at epoch {epoch} (best nRMSE={best_nrmse:.4f})")
            break
torch.save(model.state_dict(), "best_eegnet_demo_2.pt")
torch.save({"model": model.state_dict(), "optimizer": optimizer.state_dict(), "scaler_mean": demo_scaler.mean_, "scaler_scale": demo_scaler.scale_, "medians": medians}, "best_ckpt.pt")
