# %%
# !pip install  tqdm
# !pip install -U braindecode==1.2.0 mne==1.10.1 mne-bids==0.17.0 --quiet
# !pip install -U eegdash==0.3.8 s3fs==2025.9.0 fsspec==2025.9.0 pandas==2.3.3 --quiet
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 57.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.9/168.9 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 147.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.2/216.2 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 123.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 31.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.1/180.1 kB 15.4 MB/s eta 0:00:00
#   Building wheel for docopt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.9.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.

# %%
from pathlib import Path
import os, math, random
from collections import defaultdict
import importlib.util

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.nn.utils import clip_grad_norm_

from sklearn.preprocessing import StandardScaler

from braindecode.preprocessing import create_fixed_length_windows
from braindecode.datasets.base import BaseConcatDataset, BaseDataset, EEGWindowsDataset
from braindecode.models import EEGNetv4

from eegdash import EEGChallengeDataset

#Configuration and Device Setup

SFREQ = 100                # challenge downsampled sampling rate
WIN_SEC = 4                # fixed-length window size (competition examples)
CROP_SEC = 2               # random 2 s crop inside each 4 s window
STRIDE_SEC = 2             # window stride
TASK = "contrastChangeDetection"  # primary supervised task
DATADIR = Path("./data_cache")
DATADIR.mkdir(parents=True, exist_ok=True)

TRAIN_RELEASES = ["R1", "R2", "R3", "R4"]
VAL_RELEASE = "R5"

# Description fields to keep in dataset (ids + demographics + label)
DESC_FIELDS = [
    "subject", "task", "session", "run",
    "age", "sex", "gender", "handedness",
    "externalizing"
]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

def seed_all(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_all(42)

#Filtering and Loading Functions
SUB_RM = ["NDARAH793FBF", "NDARAJ689BVN"]

def filter_dataset(bcd: BaseConcatDataset):
    kept = []
    for ds in bcd.datasets:
        # Check subject not in removal list
        if ds.description["subject"] in SUB_RM:
            continue

        # Check valid label
        p_factor = ds.description.get("externalizing", np.nan)
        try:
            p_factor = float(p_factor)
            if not math.isfinite(p_factor):
                continue
        except Exception:
            continue

        # Check minimum recording length (4 seconds)
        if ds.raw.n_times < 4 * SFREQ:
            continue

        # Check for 129 channels
        if len(ds.raw.ch_names) != 129:
            continue

        kept.append(ds)

    print(f"Filtered rows: {len(kept)} (from {len(bcd.datasets)})")
    return BaseConcatDataset(kept)


def load_split(releases, task=TASK, mini=True):
    """Load multiple releases and concatenate them"""
    datasets = []
    for r in releases:
        try:
            ds = EEGChallengeDataset(
                release=r, task=task, mini=mini,
                description_fields=DESC_FIELDS, cache_dir=str(DATADIR)
            )
            datasets.append(ds)
            print(f"Loaded release {r}")
        except Exception as e:
            print(f"Warning: Could not load release {r}: {e}")
            continue

    if not datasets:
        raise ValueError("No datasets loaded successfully")

    bcd = BaseConcatDataset(datasets)
    return filter_dataset(bcd)

# 3) Demographics Processing
def extract_unique_demo(bcd: BaseConcatDataset):
    """Extract unique subject demographics (one row per subject)"""
    seen = {}
    for ds in bcd.datasets:
        sid = ds.description["subject"]
        if sid in seen:
            continue

        age = ds.description.get("age", np.nan)
        try:
            age = float(age) if age is not None and math.isfinite(float(age)) else np.nan
        except Exception:
            age = np.nan

        sex_str = str(ds.description.get("sex", ds.description.get("gender", ""))).strip().lower()
        if sex_str in ["female", "f", "2"]:
            sex = 1.0
        elif sex_str in ["male", "m", "1"]:
            sex = 0.0
        else:
            sex = np.nan

        hand = ds.description.get("handedness", np.nan)
        try:
            hand = float(hand) if hand is not None and math.isfinite(float(hand)) else np.nan
        except Exception:
            hand = np.nan

        seen[sid] = [age, sex, hand]

    arr = np.array(list(seen.values()), dtype=np.float32) if seen else np.zeros((0, 3), dtype=np.float32)
    return arr


class SafeStandardScaler(StandardScaler):
    """A robust per-column standard scaler with NaN/Inf safeguards"""
    def fit(self, X, y=None):
        super().fit(X, y)
        if hasattr(self, "scale_"):
            bad = ~np.isfinite(self.scale_) | (self.scale_ == 0)
            self.scale_[bad] = 1.0
        if hasattr(self, "var_"):
            self.var_[~np.isfinite(self.var_)] = 0.0
        if hasattr(self, "mean_"):
            self.mean_[~np.isfinite(self.mean_)] = 0.0
        return self


def build_demo_transform(train_bcd: BaseConcatDataset):
    """Build demographic transformation pipeline"""
    # Assemble unique demos
    unique = extract_unique_demo(train_bcd)
    if unique.shape[0] == 0:
        print("No demographics found; disabling late fusion.")
        return 0, None, np.zeros((0,), dtype=np.float32), np.array([], dtype=int)

    # Detect all-NaN columns
    all_nan = np.isnan(unique).all(axis=0)
    keep_mask = ~all_nan
    keep_idx = np.where(keep_mask)[0]
    keep_names = [n for n, k in zip(["age", "sex", "hand"], keep_mask) if k]
    print("Keeping demo columns:", keep_names)

    kept = unique[:, keep_idx] if keep_idx.size > 0 else np.zeros((unique.shape[0], 0), dtype=np.float32)
    if kept.shape[1] == 0:
        print("No usable demographic columns; disabling late fusion.")
        return 0, None, np.zeros((0,), dtype=np.float32), np.array([], dtype=int)

    # Compute column medians for imputation
    with np.errstate(all="ignore"):
        col_medians = np.nanmedian(kept, axis=0).astype(np.float32)
        col_medians[~np.isfinite(col_medians)] = 0.0

    # Impute and fit scaler
    def impute_cols(arr, meds):
        out = arr.copy()
        for j in range(out.shape[1]):
            mask = ~np.isfinite(out[:, j])
            out[mask, j] = meds[j]
        return out

    kept_imp = impute_cols(kept, col_medians)
    scaler = SafeStandardScaler().fit(kept_imp)
    print(f"Demo scaler fitted on {kept_imp.shape[0]} subjects | dims: {keep_idx.size}")

    def transform_batch(demo_tensor: torch.Tensor):
        if demo_tensor.numel() == 0 or keep_idx.size == 0:
            return demo_tensor.to(device=device, dtype=torch.float32)

        demo_np = demo_tensor.detach().cpu().numpy().astype(np.float32)
        # Impute per kept column using col_medians
        for j in range(demo_np.shape[1]):
            mask = ~np.isfinite(demo_np[:, j])
            demo_np[mask, j] = col_medians[j]

        demo_np = scaler.transform(demo_np)
        out = torch.from_numpy(demo_np).to(device=device, dtype=torch.float32)
        out = torch.nan_to_num(out, nan=0.0, posinf=0.0, neginf=0.0)
        return out

    return keep_idx.size, transform_batch, col_medians, keep_idx


# Dataset Wrapper with Windowing
class WindowDatasetWrapper(torch.utils.data.Dataset):
    """Wrap a WindowsDataset to apply random 2 s crop and return (X, y, demo, crop_idx, info)"""
    def __init__(self, windows_dataset: EEGWindowsDataset, crop_size_samples: int,
                 keep_idx: np.ndarray, seed: int = 42):
        self.ds = windows_dataset
        self.crop = crop_size_samples
        self.keep_idx = keep_idx
        self.rng = random.Random(seed)

    def __len__(self):
        return len(self.ds)

    def __getitem__(self, index):
        X, y, window_ind = self.ds[index]

        # Get description from the metadata
        metadata = self.ds.get_metadata()
        dataset_idx = metadata.iloc[index]['target']
        desc = self.ds.datasets[dataset_idx].description

        # Extract label (p_factor)
        p_factor = desc.get("p_factor", np.nan)
        try:
            y_val = float(p_factor) if math.isfinite(float(p_factor)) else np.nan
        except Exception:
            y_val = np.nan
        y = torch.tensor([y_val], dtype=torch.float32)

        # Extract demographics: [age, sex, hand] raw vector
        age = desc.get("age", np.nan)
        try:
            age = float(age) if age is not None and math.isfinite(float(age)) else np.nan
        except Exception:
            age = np.nan

        sex_str = str(desc.get("sex", desc.get("gender", ""))).strip().lower()
        if sex_str in ["female", "f", "2"]:
            sex = 1.0
        elif sex_str in ["male", "m", "1"]:
            sex = 0.0
        else:
            sex = np.nan

        hand = desc.get("handedness", np.nan)
        try:
            hand = float(hand) if hand is not None and math.isfinite(float(hand)) else np.nan
        except Exception:
            hand = np.nan

        # Build full demo array and select kept columns
        full_demo = np.array([age, sex, hand], dtype=np.float32)
        if len(self.keep_idx) > 0:
            demo = torch.from_numpy(full_demo[self.keep_idx])
        else:
            demo = torch.empty(0, dtype=torch.float32)

        # X comes as (C, T_window) from braindecode windows
        if not torch.is_tensor(X):
            X = torch.from_numpy(np.asarray(X))
        X = X.to(dtype=torch.float32)

        C, Tw = X.shape[-2], X.shape[-1]
        assert Tw >= self.crop, f"Window too short: {Tw} < crop {self.crop}"

        # Random crop
        start = self.rng.randint(0, Tw - self.crop)
        stop = start + self.crop
        X = X[:, start:stop]  # (C, crop)

        # Per-window z-score (time axis), sanitize
        mu = X.mean(dim=1, keepdim=True)
        sd = X.std(dim=1, keepdim=True)
        X = (X - mu) / (sd + 1e-6)
        X = torch.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0)
        X = torch.clamp(X, min=-1e3, max=1e3)

        info = dict(
            subject=desc["subject"],
            task=desc.get("task", ""),
            session=desc.get("session", ""),
            run=desc.get("run", "")
        )
        crop_idx = (start, stop)

        return X, y, demo, crop_idx, info


def make_windows(bcd: BaseConcatDataset, keep_idx: np.ndarray,
                 win_sec=WIN_SEC, crop_sec=CROP_SEC):
    """Create fixed-length windows with random cropping"""
    windows = create_fixed_length_windows(
        bcd,
        window_size_samples=int(win_sec * SFREQ),
        window_stride_samples=int(STRIDE_SEC * SFREQ),
        drop_last_window=True,
    )
    wrapped = WindowDatasetWrapper(
        windows,
        crop_size_samples=int(crop_sec * SFREQ),
        keep_idx=keep_idx,
        seed=42
    )
    return wrapped


# Load and Process Data
print("\n" + "="*60)
print("Loading training releases...")
print("="*60)
train_bcd = load_split(TRAIN_RELEASES, task=TASK, mini=True)

print("\n" + "="*60)
print("Loading validation release...")
print("="*60)
val_bcd = load_split([VAL_RELEASE], task=TASK, mini=True)

# Fit demographics transform on TRAIN ONLY
demodim, transform_demo_batch, demo_medians, keep_idx = build_demo_transform(train_bcd)

# Create windows
print("\n" + "="*60)
print("Creating windows...")
print("="*60)
train_windows = make_windows(train_bcd, keep_idx, WIN_SEC, CROP_SEC)
val_windows = make_windows(val_bcd, keep_idx, WIN_SEC, CROP_SEC)

# DataLoaders
BATCH_SIZE = 32
train_loader = DataLoader(train_windows, batch_size=BATCH_SIZE, shuffle=True,
                         num_workers=0, pin_memory=True)
val_loader = DataLoader(val_windows, batch_size=BATCH_SIZE, shuffle=False,
                       num_workers=0, pin_memory=True)

print(f"Train batches: {len(train_loader)} | Val batches: {len(val_loader)}")

# Infer shapes for model init
sample_X, sample_y, sample_demo, _, _ = train_windows[0]
C, T = sample_X.shape[-2], sample_X.shape[-1]
print(f"Sample window shape: ({C}, {T}) | demodim: {demodim}")
# Out:
# Using device: cuda
#
# ============================================================
# Loading training releases...
# ============================================================
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# Loaded release R1
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# Loaded release R2
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# Loaded release R3
# /usr/local/lib/python3.12/dist-packages/eegdash/dataset/dataset.py:126: UserWarning:
#
# [EEGChallengeDataset] EEG 2025 Competition Data Notice:
# -------------------------------------------------------
# This object loads the HBN dataset that has been preprocessed for the EEG Challenge:
#   - Downsampled from 500Hz to 100Hz
#   - Bandpass filtered (0.5–50 Hz)
#
# For full preprocessing details, see:
#   https://github.com/eeg2025/downsample-datasets
#
# IMPORTANT: The data accessed via `EEGChallengeDataset` is NOT identical to what you get from `EEGDashDataset` directly.
# If you are participating in the competition, always use `EEGChallengeDataset` to ensure consistency with the challenge data.
#
#
#   warn(
# Loaded release R4
# Downloading sub-NDARAP359UM6_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARAP359UM6_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.20B/s]
#
# Downloading sub-NDARAP359UM6_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARAP359UM6_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.60B/s]
#
# Downloading sub-NDARBD879MBX_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.00B/s]
#
# Downloading sub-NDARBD879MBX_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.37B/s]
#
# Downloading sub-NDARBD879MBX_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
#
# Downloading sub-NDARBD879MBX_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.05B/s]
#
# Downloading sub-NDARBD879MBX_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.99B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.48B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.98B/s]
#
# Downloading sub-NDARBD879MBX_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.43B/s]
#
# Downloading sub-NDARBD879MBX_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.25B/s]
#
# Downloading sub-NDARBD879MBX_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.20B/s]
#
# Downloading sub-NDARBD879MBX_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.96B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.08B/s]
#
# Downloading sub-NDARBD879MBX_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.39B/s]
#
# Downloading sub-NDARBD879MBX_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.58B/s]
#
# Downloading sub-NDARBD879MBX_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.87B/s]
#
# Downloading sub-NDARBD879MBX_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.73B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.19B/s]
#
# Downloading sub-NDARBD879MBX_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
#
# Downloading sub-NDARBD879MBX_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
#
# Downloading sub-NDARBD879MBX_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.49B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARBD879MBX_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
#
# Downloading sub-NDARBD879MBX_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
#
# Downloading sub-NDARBD879MBX_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.15B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.11B/s]
#
# Downloading sub-NDARBD879MBX_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.80B/s]
#
# Downloading sub-NDARBD879MBX_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.52B/s]
#
# Downloading sub-NDARBD879MBX_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
#
# Downloading sub-NDARBD879MBX_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.98B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.09B/s]
#
# Downloading sub-NDARBD879MBX_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.11B/s]
#
# Downloading sub-NDARBD879MBX_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.43B/s]
#
# Downloading sub-NDARBD879MBX_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.58B/s]
#
# Downloading sub-NDARBD879MBX_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.62B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.27B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.82B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.08B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.85B/s]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.20s/B]
#
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBD879MBX_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.44s/B]
#
# Downloading sub-NDARBH024NH2_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.37B/s]
#
# Downloading sub-NDARBH024NH2_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.14B/s]
#
# Downloading sub-NDARBH024NH2_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.22B/s]
#
# Downloading sub-NDARBH024NH2_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.93B/s]
#
# Downloading sub-NDARBH024NH2_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
#
# Downloading sub-NDARBH024NH2_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
#
# Downloading sub-NDARBH024NH2_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.83B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
#
# Downloading sub-NDARBH024NH2_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
#
# Downloading sub-NDARBH024NH2_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.47B/s]
#
# Downloading sub-NDARBH024NH2_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.41B/s]
#
# Downloading sub-NDARBH024NH2_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.85B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.14B/s]
#
# Downloading sub-NDARBH024NH2_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
#
# Downloading sub-NDARBH024NH2_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
#
# Downloading sub-NDARBH024NH2_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.25B/s]
#
# Downloading sub-NDARBH024NH2_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.25B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.07B/s]
#
# Downloading sub-NDARBH024NH2_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.38B/s]
#
# Downloading sub-NDARBH024NH2_task-DiaryOfAWimpyKid_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBH024NH2_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.11B/s]
#
# Downloading sub-NDARBH024NH2_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.46B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
#
# Downloading sub-NDARBH024NH2_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
#
# Downloading sub-NDARBH024NH2_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.10B/s]
#
# Downloading sub-NDARBH024NH2_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.00B/s]
#
# Downloading sub-NDARBH024NH2_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
#
# Downloading sub-NDARBH024NH2_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.34B/s]
#
# Downloading sub-NDARBH024NH2_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.58B/s]
#
# Downloading sub-NDARBH024NH2_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.54B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
#
# Downloading sub-NDARBH024NH2_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.16B/s]
#
# Downloading sub-NDARBH024NH2_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.36B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.25B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.22B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.28B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.35B/s]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.15s/B]
#
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBH024NH2_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.08s/B]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.06B/s]
#
# Downloading sub-NDARBK082PDD_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.30B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
#
# Downloading sub-NDARBK082PDD_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.94B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.12B/s]
#
# Downloading sub-NDARBK082PDD_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.13B/s]
#
# Downloading sub-NDARBK082PDD_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.73B/s]
#
# Downloading sub-NDARBK082PDD_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
#
# Downloading sub-NDARBK082PDD_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.62B/s]
#
# Downloading sub-NDARBK082PDD_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.97B/s]
#
# Downloading sub-NDARBK082PDD_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.86B/s]
#
# Downloading sub-NDARBK082PDD_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.55B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.51B/s]
#
# Downloading sub-NDARBK082PDD_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.79B/s]
#
# Downloading sub-NDARBK082PDD_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.82B/s]
#
# Downloading sub-NDARBK082PDD_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.25B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.02B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
#
# Downloading sub-NDARBK082PDD_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.89B/s]
#
# Downloading sub-NDARBK082PDD_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.81B/s]
#
# Downloading sub-NDARBK082PDD_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.85B/s]
#
# Downloading sub-NDARBK082PDD_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.98B/s]
#
# Downloading sub-NDARBK082PDD_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
#
# Downloading sub-NDARBK082PDD_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.07B/s]
#
# Downloading sub-NDARBK082PDD_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.70B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.22B/s]
#
# Downloading sub-NDARBK082PDD_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.98B/s]
#
# Downloading sub-NDARBK082PDD_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.24B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.82B/s]
#
# Downloading sub-NDARBK082PDD_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.05B/s]
#
# Downloading sub-NDARBK082PDD_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.83B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.25B/s]
#
# Downloading sub-NDARBK082PDD_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.54B/s]
#
# Downloading sub-NDARBK082PDD_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
#
# Downloading sub-NDARBK082PDD_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
#
# Downloading sub-NDARBK082PDD_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.90B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.40B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.88B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.02B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.15s/B]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.66B/s]
#
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBK082PDD_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.82B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
#
# Downloading sub-NDARCA153NKE_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.04B/s]
#
# Downloading sub-NDARCA153NKE_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.13B/s]
#
# Downloading sub-NDARCA153NKE_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.49B/s]
#
# Downloading sub-NDARCA153NKE_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.23B/s]
#
# Downloading sub-NDARCA153NKE_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.59B/s]
#
# Downloading sub-NDARCA153NKE_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.68B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.79B/s]
#
# Downloading sub-NDARCA153NKE_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.95B/s]
#
# Downloading sub-NDARCA153NKE_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.54B/s]
#
# Downloading sub-NDARCA153NKE_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.88B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.40B/s]
#
# Downloading sub-NDARCA153NKE_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.25B/s]
#
# Downloading sub-NDARCA153NKE_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.11B/s]
#
# Downloading sub-NDARCA153NKE_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.15B/s]
#
# Downloading sub-NDARCA153NKE_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.89B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.19B/s]
#
# Downloading sub-NDARCA153NKE_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.92B/s]
#
# Downloading sub-NDARCA153NKE_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.59B/s]
#
# Downloading sub-NDARCA153NKE_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.34B/s]
#
# Downloading sub-NDARCA153NKE_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.83B/s]
#
# Downloading sub-NDARCA153NKE_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.57B/s]
#
# Downloading sub-NDARCA153NKE_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.60B/s]
#
# Downloading sub-NDARCA153NKE_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.09B/s]
#
# Downloading sub-NDARCA153NKE_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.71B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.72B/s]
#
# Downloading sub-NDARCA153NKE_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.10B/s]
#
# Downloading sub-NDARCA153NKE_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.26B/s]
#
# Downloading sub-NDARCA153NKE_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.60B/s]
#
# Downloading sub-NDARCA153NKE_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.65B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.68B/s]
#
# Downloading sub-NDARCA153NKE_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.51B/s]
#
# Downloading sub-NDARCA153NKE_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.77B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.51B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.18B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.71B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.05B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.74B/s]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.01s/B]
#
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCA153NKE_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.12B/s]
#
# Downloading sub-NDARCE721YB5_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.39B/s]
#
# Downloading sub-NDARCE721YB5_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.68B/s]
#
# Downloading sub-NDARCE721YB5_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.22B/s]
#
# Downloading sub-NDARCE721YB5_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
#
# Downloading sub-NDARCE721YB5_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.90B/s]
#
# Downloading sub-NDARCE721YB5_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.71B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
#
# Downloading sub-NDARCE721YB5_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.10B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
#
# Downloading sub-NDARCE721YB5_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.58B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.08B/s]
#
# Downloading sub-NDARCE721YB5_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.93B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.46B/s]
#
# Downloading sub-NDARCE721YB5_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
#
# Downloading sub-NDARCE721YB5_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
#
# Downloading sub-NDARCE721YB5_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
#
# Downloading sub-NDARCE721YB5_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.27B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.87B/s]
#
# Downloading sub-NDARCE721YB5_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.35B/s]
#
# Downloading sub-NDARCE721YB5_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
#
# Downloading sub-NDARCE721YB5_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.07B/s]
#
# Downloading sub-NDARCE721YB5_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.56B/s]
#
# Downloading sub-NDARCE721YB5_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
#
# Downloading sub-NDARCE721YB5_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.03B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARCE721YB5_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.09B/s]
#
# Downloading sub-NDARCE721YB5_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.01B/s]
#
# Downloading sub-NDARCE721YB5_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.43B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.27B/s]
#
# Downloading sub-NDARCE721YB5_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.83B/s]
#
# Downloading sub-NDARCE721YB5_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.20B/s]
#
# Downloading sub-NDARCE721YB5_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
#
# Downloading sub-NDARCE721YB5_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
#
# Downloading sub-NDARCE721YB5_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.09B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.21B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.66B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.02s/B]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.09B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.16B/s]
#
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCE721YB5_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.26B/s]
#
# Downloading sub-NDARCJ594BWQ_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.15B/s]
#
# Downloading sub-NDARCJ594BWQ_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.74B/s]
#
# Downloading sub-NDARCJ594BWQ_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.81B/s]
#
# Downloading sub-NDARCJ594BWQ_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.79B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.22B/s]
#
# Downloading sub-NDARCJ594BWQ_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.09B/s]
#
# Downloading sub-NDARCJ594BWQ_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
#
# Downloading sub-NDARCJ594BWQ_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.25B/s]
#
# Downloading sub-NDARCJ594BWQ_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.09B/s]
#
# Downloading sub-NDARCJ594BWQ_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.13B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.77B/s]
#
# Downloading sub-NDARCJ594BWQ_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.02B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.76B/s]
#
# Downloading sub-NDARCJ594BWQ_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.31B/s]
#
# Downloading sub-NDARCJ594BWQ_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.44B/s]
#
# Downloading sub-NDARCJ594BWQ_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARCJ594BWQ_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.92B/s]
#
# Downloading sub-NDARCJ594BWQ_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.97B/s]
#
# Downloading sub-NDARCJ594BWQ_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
#
# Downloading sub-NDARCJ594BWQ_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]
#
# Downloading sub-NDARCJ594BWQ_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.09B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.87B/s]
#
# Downloading sub-NDARCJ594BWQ_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
#
# Downloading sub-NDARCJ594BWQ_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.29B/s]
#
# Downloading sub-NDARCJ594BWQ_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.46B/s]
#
# Downloading sub-NDARCJ594BWQ_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.17B/s]
#
# Downloading sub-NDARCJ594BWQ_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.94B/s]
#
# Downloading sub-NDARCJ594BWQ_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.36B/s]
#
# Downloading sub-NDARCJ594BWQ_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.83B/s]
#
# Downloading sub-NDARCJ594BWQ_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.98B/s]
#
# Downloading sub-NDARCJ594BWQ_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.29B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.88B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.59B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.36B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.94B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.03B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.53B/s]
#
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCJ594BWQ_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.14B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.89B/s]
#
# Downloading sub-NDARCN669XPR_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.48B/s]
#
# Downloading sub-NDARCN669XPR_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.15B/s]
#
# Downloading sub-NDARCN669XPR_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.85B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.78B/s]
#
# Downloading sub-NDARCN669XPR_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.31B/s]
#
# Downloading sub-NDARCN669XPR_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.29B/s]
#
# Downloading sub-NDARCN669XPR_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.58B/s]
#
# Downloading sub-NDARCN669XPR_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.78B/s]
#
# Downloading sub-NDARCN669XPR_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.38B/s]
#
# Downloading sub-NDARCN669XPR_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.89B/s]
#
# Downloading sub-NDARCN669XPR_task-seqLearning8target_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCN669XPR_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.20B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.13B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.01B/s]
#
# Downloading sub-NDARCN669XPR_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.09B/s]
#
# Downloading sub-NDARCN669XPR_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.90B/s]
#
# Downloading sub-NDARCN669XPR_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.61B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.19B/s]
#
# Downloading sub-NDARCN669XPR_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.96B/s]
#
# Downloading sub-NDARCN669XPR_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.88B/s]
#
# Downloading sub-NDARCN669XPR_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.77B/s]
#
# Downloading sub-NDARCN669XPR_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
#
# Downloading sub-NDARCN669XPR_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.53B/s]
#
# Downloading sub-NDARCN669XPR_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
#
# Downloading sub-NDARCN669XPR_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.62B/s]
#
# Downloading sub-NDARCN669XPR_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.25B/s]
#
# Downloading sub-NDARCN669XPR_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.59B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.15B/s]
#
# Downloading sub-NDARCN669XPR_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.63B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.64B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.97B/s]
#
# Downloading sub-NDARCN669XPR_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.09B/s]
#
# Downloading sub-NDARCN669XPR_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
#
# Downloading sub-NDARCN669XPR_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.52B/s]
#
# Downloading sub-NDARCN669XPR_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.42B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.24B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.67B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.11s/B]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.02s/B]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.63B/s]
#
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCN669XPR_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.66B/s]
#
# Downloading sub-NDARCW094JCG_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.46B/s]
#
# Downloading sub-NDARCW094JCG_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
#
# Downloading sub-NDARCW094JCG_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.62B/s]
#
# Downloading sub-NDARCW094JCG_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.21B/s]
#
# Downloading sub-NDARCW094JCG_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.82B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
#
# Downloading sub-NDARCW094JCG_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.16B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.40B/s]
#
# Downloading sub-NDARCW094JCG_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
#
# Downloading sub-NDARCW094JCG_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.94B/s]
#
# Downloading sub-NDARCW094JCG_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.72B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.41B/s]
#
# Downloading sub-NDARCW094JCG_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.97B/s]
#
# Downloading sub-NDARCW094JCG_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.63B/s]
#
# Downloading sub-NDARCW094JCG_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.81B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.77B/s]
#
# Downloading sub-NDARCW094JCG_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.23B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.68B/s]
#
# Downloading sub-NDARCW094JCG_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
#
# Downloading sub-NDARCW094JCG_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
#
# Downloading sub-NDARCW094JCG_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.32B/s]
#
# Downloading sub-NDARCW094JCG_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.38B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.96B/s]
#
# Downloading sub-NDARCW094JCG_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.85B/s]
#
# Downloading sub-NDARCW094JCG_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.25B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.94B/s]
#
# Downloading sub-NDARCW094JCG_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.27B/s]
#
# Downloading sub-NDARCW094JCG_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.65B/s]
#
# Downloading sub-NDARCW094JCG_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.45B/s]
#
# Downloading sub-NDARCW094JCG_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.36B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.19B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.03B/s]
#
# Downloading sub-NDARCW094JCG_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.17B/s]
#
# Downloading sub-NDARCW094JCG_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.82B/s]
#
# Downloading sub-NDARCW094JCG_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.50B/s]
#
# Downloading sub-NDARCW094JCG_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.52B/s]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.33s/B]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.29s/B]
#
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARCW094JCG_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.33B/s]
#
# ...
#
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.13B/s]
#
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.46B/s]
#
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.69B/s]
#
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.25B/s]
#
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBE641DGZ_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.29B/s]
#
# Downloading sub-NDARBG574KF4_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.95B/s]
#
# Downloading sub-NDARBG574KF4_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.98B/s]
#
# Downloading sub-NDARBG574KF4_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.96B/s]
#
# Downloading sub-NDARBG574KF4_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.66B/s]
#
# Downloading sub-NDARBG574KF4_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.97B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.74B/s]
#
# Downloading sub-NDARBG574KF4_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.55B/s]
#
# Downloading sub-NDARBG574KF4_task-seqLearning6target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
#
# Downloading sub-NDARBG574KF4_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.77B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.91B/s]
#
# Downloading sub-NDARBG574KF4_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.05B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.97B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.65B/s]
#
# Downloading sub-NDARBG574KF4_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.86B/s]
#
# Downloading sub-NDARBG574KF4_task-seqLearning6target_eeg.json:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBG574KF4_task-seqLearning6target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.27B/s]
#
# Downloading sub-NDARBG574KF4_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.98B/s]
#
# Downloading sub-NDARBG574KF4_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.63B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.21B/s]
#
# Downloading sub-NDARBG574KF4_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.68B/s]
#
# Downloading sub-NDARBG574KF4_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.29B/s]
#
# Downloading sub-NDARBG574KF4_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.10B/s]
#
# Downloading sub-NDARBG574KF4_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.83B/s]
#
# Downloading sub-NDARBG574KF4_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.49B/s]
#
# Downloading sub-NDARBG574KF4_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.26B/s]
#
# Downloading sub-NDARBG574KF4_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.90B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.01B/s]
#
# Downloading sub-NDARBG574KF4_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.55B/s]
#
# Downloading sub-NDARBG574KF4_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.96B/s]
#
# Downloading sub-NDARBG574KF4_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.55B/s]
#
# Downloading sub-NDARBG574KF4_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.56B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.18B/s]
#
# Downloading sub-NDARBG574KF4_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.79B/s]
#
# Downloading sub-NDARBG574KF4_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.17B/s]
#
# Downloading sub-NDARBG574KF4_task-seqLearning6target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.01B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:01<00:00, 1.15s/B]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.32B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.55B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.07B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.26B/s]
#
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBG574KF4_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.47B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.29B/s]
#
# Downloading sub-NDARBM642JFT_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.04B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
#
# Downloading sub-NDARBM642JFT_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.27B/s]
#
# Downloading sub-NDARBM642JFT_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.03B/s]
#
# Downloading sub-NDARBM642JFT_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 3.23B/s]
#
# Downloading sub-NDARBM642JFT_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.99B/s]
#
# Downloading sub-NDARBM642JFT_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
#
# Downloading sub-NDARBM642JFT_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.87B/s]
#
# Downloading sub-NDARBM642JFT_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.89B/s]
#
# Downloading sub-NDARBM642JFT_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.06B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.22B/s]
#
# Downloading sub-NDARBM642JFT_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARBM642JFT_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.75B/s]
#
# Downloading sub-NDARBM642JFT_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.48B/s]
#
# Downloading sub-NDARBM642JFT_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
#
# Downloading sub-NDARBM642JFT_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.25B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.33B/s]
#
# Downloading sub-NDARBM642JFT_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.10B/s]
#
# Downloading sub-NDARBM642JFT_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.35B/s]
#
# Downloading sub-NDARBM642JFT_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.61B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.93B/s]
#
# Downloading sub-NDARBM642JFT_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.51B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.47B/s]
#
# Downloading sub-NDARBM642JFT_task-surroundSupp_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.20B/s]
#
# Downloading sub-NDARBM642JFT_task-surroundSupp_run-2_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.14B/s]
#
# Downloading sub-NDARBM642JFT_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.85B/s]
#
# Downloading sub-NDARBM642JFT_task-ThePresent_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.29B/s]
#
# Downloading sub-NDARBM642JFT_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.51B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-1_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-3_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.30B/s]
#
# Downloading sub-NDARBM642JFT_task-FunwithFractals_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.90B/s]
#
# Downloading sub-NDARBM642JFT_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.66B/s]
#
# Downloading sub-NDARBM642JFT_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.14B/s]
#
# Downloading sub-NDARBM642JFT_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.45B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.33B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-3_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-3_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.81B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.20B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-2_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-2_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.07B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 2.07B/s]
#
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-1_eeg.bdf:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading sub-NDARBM642JFT_task-contrastChangeDetection_run-1_eeg.bdf: 100%|██████████| 1.00/1.00 [00:00<00:00, 1.93B/s]
#
# Downloading sub-NDARCL016NHB_task-surroundSupp_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.60B/s]
#
# Downloading sub-NDARCL016NHB_task-RestingState_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.73B/s]
#
# Downloading sub-NDARCL016NHB_task-symbolSearch_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.43B/s]
#
# Downloading sub-NDARCL016NHB_task-FunwithFractals_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.44B/s]
#
# Downloading sub-NDARCL016NHB_task-DiaryOfAWimpyKid_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.41B/s]
#
# Downloading sub-NDARCL016NHB_task-contrastChangeDetection_run-2_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARCL016NHB_task-seqLearning8target_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.51B/s]
#
# Downloading sub-NDARCL016NHB_task-contrastChangeDetection_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.94B/s]
#
# Downloading sub-NDARCL016NHB_task-surroundSupp_run-1_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.06B/s]
#
# Downloading sub-NDARCL016NHB_task-DespicableMe_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.64B/s]
#
# Downloading sub-NDARCL016NHB_task-contrastChangeDetection_run-3_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.02B/s]
#
# Downloading sub-NDARCL016NHB_task-ThePresent_events.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 7.07B/s]
#
# Downloading sub-NDARCL016NHB_task-contrastChangeDetection_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.29B/s]
#
# Downloading sub-NDARCL016NHB_task-seqLearning8target_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.24B/s]
#
# Downloading sub-NDARCL016NHB_task-ThePresent_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.17B/s]
#
# Downloading sub-NDARCL016NHB_task-surroundSupp_run-2_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 4.98B/s]
#
# Downloading sub-NDARCL016NHB_task-RestingState_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.13B/s]
#
# Downloading sub-NDARCL016NHB_task-symbolSearch_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.41B/s]
#
# Downloading sub-NDARCL016NHB_task-surroundSupp_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.98B/s]
#
# Downloading sub-NDARCL016NHB_task-DespicableMe_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.87B/s]
#
# Downloading sub-NDARCL016NHB_task-contrastChangeDetection_run-1_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.37B/s]
#
# Downloading sub-NDARCL016NHB_task-DiaryOfAWimpyKid_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.52B/s]
#
# Downloading sub-NDARCL016NHB_task-contrastChangeDetection_run-3_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.12B/s]
#
# Downloading sub-NDARCL016NHB_task-FunwithFractals_eeg.json: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.81B/s]
#
# Downloading sub-NDARCL016NHB_task-DiaryOfAWimpyKid_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.28B/s]
#
# Downloading sub-NDARCL016NHB_task-symbolSearch_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.33B/s]
#
# Downloading sub-NDARCL016NHB_task-RestingState_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 6.15B/s]
#
# Downloading sub-NDARCL016NHB_task-seqLearning8target_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.58B/s]
#
# Downloading sub-NDARCL016NHB_task-DespicableMe_channels.tsv: 100%|██████████| 1.00/1.00 [00:00<00:00, 5.84B/s]

# %%
# Load Enhanced Model
MODEL_PATH = "/content/enhanced_eegnet.py"
if not Path(MODEL_PATH).exists():
    print(f"\n{'='*60}")
    print("ERROR: Please upload enhanced_eegnet.py to /content/")
    print("="*60)
else:
    spec = importlib.util.spec_from_file_location("enhanced_eegnet", MODEL_PATH)
    ee_module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(ee_module)

    EnhancedEEGNetRegressor = ee_module.EnhancedEEGNetRegressor
    RMSELoss = getattr(ee_module, "RMSELoss", None)
    NRMSELoss = getattr(ee_module, "NRMSELoss", None)
    adapt_batch_norm = getattr(ee_module, "adapt_batch_norm", None)

    model = EnhancedEEGNetRegressor(
        n_channels=C,           # e.g., 129
        n_times=T,              # 2 s * 100 Hz = 200
        n_demographic_features=demodim,
        dropout=0.5,
        F1=16,
        D=2,
        num_heads=8
    ).to(device)

    print(f"\nModel initialized with {sum(p.numel() for p in model.parameters()):,} parameters")


#Evaluation Function
@torch.no_grad()
def evaluate_subject_nrmse(model, loader):
    """Evaluate subject-level nRMSE"""
    model.eval()
    subj_pred, subj_true = defaultdict(list), {}

    for X, y, demo, crop_idx, info in tqdm(loader, desc="Validation", leave=False):
        X = X.to(device=device, dtype=torch.float32)            # (B, C, T)
        X = X.unsqueeze(1)                                      # (B, 1, C, T)
        y = y.to(device=device, dtype=torch.float32)            # (B, 1)
        demo = demo.to(device=device, dtype=torch.float32)

        if demodim > 0:
            demo = transform_demo_batch(demo)
        else:
            demo = torch.empty((X.size(0), 0), device=device, dtype=torch.float32)

        preds = model(X, demographics=demo).squeeze(1).detach().cpu().numpy()
        ys = y.squeeze(1).detach().cpu().numpy()

        # Handle info dict
        for i in range(len(preds)):
            sid = info["subject"][i] if isinstance(info, dict) else info[i]["subject"]
            subj_pred[sid].append(float(preds[i]))
            subj_true[sid] = float(ys[i])

    if len(subj_pred) == 0:
        return np.nan, np.nan, np.nan, 0

    ytrue, yhat, sids = [], [], []
    for sid, plist in subj_pred.items():
        if sid not in subj_true or len(plist) == 0:
            continue
        ytrue.append(subj_true[sid])
        yhat.append(float(np.mean(plist)))
        sids.append(sid)

    ytrue = np.array(ytrue, dtype=np.float64)
    yhat = np.array(yhat, dtype=np.float64)
    rmse = float(np.sqrt(np.mean((ytrue - yhat) ** 2))) if ytrue.size > 0 else np.nan
    stdy = float(np.std(ytrue, ddof=0)) if ytrue.size > 0 else np.nan
    nrmse = rmse / stdy if stdy and stdy > 0 else np.nan

    # Save per-subject predictions
    out_dir = Path("./outputs")
    out_dir.mkdir(parents=True, exist_ok=True)
    pd.DataFrame({
        "subject": sids,
        "p_factor_pred": yhat,
        "p_factor_true": ytrue
    }).to_csv(out_dir / "val_subject_predictions.csv", index=False)

    return nrmse, rmse, stdy, len(sids)

# Training Function
def train_model(model, train_loader, val_loader, max_epochs=40, lr=1e-3,
                weight_decay=1e-2, patience=8, use_nrmse_loss=True):
    """Train the model with early stopping"""
    # Loss function
    if use_nrmse_loss and NRMSELoss is not None:
        criterion = NRMSELoss()
        print("Using NRMSELoss for training.")
    elif RMSELoss is not None:
        criterion = RMSELoss()
        print("Using RMSELoss for training.")
    else:
        criterion = nn.MSELoss()
        print("Using MSELoss for training.")

    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=3
    )

    best_nrmse, wait = float("inf"), 0
    ckpt_dir = Path("./checkpoints")
    ckpt_dir.mkdir(parents=True, exist_ok=True)
    ckpt_path = ckpt_dir / "best_enhanced_eegnet.pt"

    for epoch in range(1, max_epochs + 1):
        model.train()
        train_loss_sum, n_seen = 0.0, 0

        pbar = tqdm(train_loader, desc=f"Epoch {epoch:02d} • Train", leave=False)
        for X, y, demo, crop_idx, info in pbar:
            X = X.to(device=device, dtype=torch.float32)   # (B, C, T)
            X = X.unsqueeze(1)                             # (B, 1, C, T)
            y = y.to(device=device, dtype=torch.float32)   # (B, 1)
            demo = demo.to(device=device, dtype=torch.float32)

            if demodim > 0:
                demo = transform_demo_batch(demo)
            else:
                demo = torch.empty((X.size(0), 0), device=device, dtype=torch.float32)

            optimizer.zero_grad(set_to_none=True)
            y_pred = model(X, demographics=demo)
            loss = criterion(y_pred, y)

            if not torch.isfinite(loss):
                print("Non-finite loss; skipping batch.")
                continue

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss_sum += loss.item() * X.size(0)
            n_seen += X.size(0)
            pbar.set_postfix(loss=loss.item())

        train_loss = train_loss_sum / max(1, n_seen)

        # Validate subject-level metrics
        nrmse, rmse, stdy, nsubj = evaluate_subject_nrmse(model, val_loader)
        scheduler.step(nrmse if nrmse == nrmse else 1.0)

        print(f"Epoch {epoch:02d} • train loss {train_loss:.4f} • val nRMSE {nrmse:.4f} • " +
              f"RMSE {rmse:.4f} • std(y) {stdy:.4f} • subjects {nsubj}")

        improved = (nrmse < best_nrmse) if nrmse == nrmse else False
        if improved:
            best_nrmse, wait = nrmse, 0
            torch.save(model.state_dict(), ckpt_path)
            print(f"✓ Saved {ckpt_path} • best nRMSE {best_nrmse:.4f}")
        else:
            wait += 1
            if wait >= patience:
                print(f"Early stopping at epoch {epoch} • best nRMSE {best_nrmse:.4f}")
                break

    # Load best checkpoint
    if ckpt_path.exists():
        model.load_state_dict(torch.load(ckpt_path, map_location=device))
        print(f"Loaded best checkpoint: {ckpt_path}")

    return model, best_nrmse


#Run Training
if Path(MODEL_PATH).exists():
    print("\n" + "="*60)
    print("Starting training...")
    print("="*60)
    model, best_nrmse = train_model(
        model, train_loader, val_loader,
        max_epochs=40, lr=1e-3, weight_decay=1e-2,
        patience=8, use_nrmse_loss=True
    )

    # AdaBN on validation domain
    if adapt_batch_norm is not None:
        print("\n" + "="*60)
        print("Adapting BatchNorm on validation domain (AdaBN)...")
        print("="*60)
        adapt_batch_norm(model, val_loader, device)

    # Final validation report
    print("\n" + "="*60)
    print("Final evaluation...")
    print("="*60)
    nrmse, rmse, stdy, nsubj = evaluate_subject_nrmse(model, val_loader)
    print(f"Final • val nRMSE {nrmse:.4f} • RMSE {rmse:.4f} • " +
          f"std(y) {stdy:.4f} • subjects {nsubj}")
    print("Results saved to: ./outputs/val_subject_predictions.csv")
else:
    print("\nUpload enhanced_eegnet.py to /content/ and re-run the cells.")
